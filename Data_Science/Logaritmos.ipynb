# %% [markdown]
# <h1>Logaritmos</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(rc={'figure.figsize':(12,9)})
pd.set_option('use_inf_as_na', True)

# %%
#arr = pd.DataFrame(np.arange(100).reshape(10,10),columns=list('ABCDEFGHIJ'))
arr = pd.DataFrame(np.arange(1000),columns=['A'])
arr= arr.pow(2)

# %%
arr.head(3)
# Out:
#    A
# 0  0
# 1  1
# 2  4

# %%
log = np.log10(arr)
#log.replace([np.inf, -np.inf], np.nan)
log
# Out:
# <ipython-input-57-4ae3ddf7d126>:1: RuntimeWarning: divide by zero encountered in log10
#   log = np.log10(arr)
#             A
# 0         NaN
# 1    0.000000
# 2    0.602060
# 3    0.954243
# 4    1.204120
# ..        ...
# 995  5.995646
# 996  5.996519
# 997  5.997390
# 998  5.998261
# 999  5.999131
#
# [1000 rows x 1 columns]

# %%
pow(10,0.301030)
# Out:
# 2.0000000199681045

# %%
plt.plot(log)
#plt.xscale('log')

# %%
sns.distplot(log)
