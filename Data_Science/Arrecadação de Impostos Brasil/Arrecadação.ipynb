# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas_datareader.data as web

# %%
arr=pd.read_csv('Arrecadação por UF - Internet - Jan a Dez19.csv')

# %%
arr
# Out:
#                                              RECEITAS             AC  \
# 0                            IMPOSTO SOBRE IMPORTAÇÃO        685.638
# 1                            IMPOSTO SOBRE EXPORTAÇÃO            677
# 2                                         IPI - TOTAL      4.088.847
# 3                                          IPI - FUMO             00
# 4                                       IPI - BEBIDAS      2.070.609
# 5                                    IPI - AUTOMÓVEIS         70.526
# 6                        IPI - VINCULADO À IMPORTACAO      1.605.701
# 7                                        IPI - OUTROS        342.012
# 8                       IMPOSTO SOBRE A RENDA - TOTAL    274.853.657
# 9                                                IRPF     65.219.583
# 10                                               IRPJ     87.592.352
# 11                              ENTIDADES FINANCEIRAS         78.476
# 12                                    DEMAIS EMPRESAS     87.513.876
# ...

# %%
arr.index
# Out:
# RangeIndex(start=0, stop=37, step=1)
