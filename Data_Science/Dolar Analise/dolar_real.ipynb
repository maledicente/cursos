# %% [markdown]
# <h1>Analise do valor do dolar.<h1/>

# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns

# %%
# %matplotlib inline
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
start = datetime.datetime(2003,12,1)
end = datetime.datetime(2020,10,1)

# %%
dolar_real = data.DataReader('USDBRL=X','yahoo', start, end)
real_peso_ar = data.DataReader('BRLARS=X','yahoo', start, end)
#list_ticker = pd.read_excel('Yahoo Ticker Symbols - September 2017.xlsx')
dolar_real.to_csv('dolar_real.csv')
#list_ticker.to_csv('list_ticker.csv')

# %%
dolar_real.head()
# Out:
#              High    Low   Open  Close  Volume  Adj Close
# Date
# 2003-12-01  2.946  2.923  2.946  2.923     0.0      2.923
# 2003-12-02  2.931  2.923  2.923  2.931     0.0      2.931
# 2003-12-03  2.936  2.926  2.931  2.931     0.0      2.931
# 2003-12-04  2.943  2.931  2.931  2.943     0.0      2.943
# 2003-12-05  2.948  2.934  2.943  2.934     0.0      2.934

# %%
dolar_real.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3948 entries, 2003-12-01 to 2020-10-01
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       3948 non-null   float64
#  1   Low        3948 non-null   float64
#  2   Open       3948 non-null   float64
#  3   Close      3948 non-null   float64
#  4   Volume     3948 non-null   float64
#  5   Adj Close  3948 non-null   float64
# dtypes: float64(6)
# memory usage: 215.9 KB

# %%
dolar_real['Adj Close'].plot()

# %%
d=dolar_real.loc[dolar_real['High'] > 4]
d['High'].plot()
